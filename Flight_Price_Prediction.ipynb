# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Dataset.csv")

# %%
df.shape
# Out:
# (300153, 12)

# %%
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
df.drop(df.columns[0],axis='columns',inplace=True)

# %%
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
sns.boxplot(x=df.airline,y=df.price)
# Out:
# <Axes: xlabel='airline', ylabel='price'>

# %%
sns.barplot(x=df.source_city,y=df.price)
# Out:
# <Axes: xlabel='source_city', ylabel='price'>

# %%
sns.boxplot(x=df.departure_time,y=df.price)
# Out:
# <Axes: xlabel='departure_time', ylabel='price'>

# %%
sns.boxplot(x=df.stops,y=df.price)
# Out:
# <Axes: xlabel='stops', ylabel='price'>

# %%
sns.boxplot(x=df.arrival_time,y=df.price)
# Out:
# <Axes: xlabel='arrival_time', ylabel='price'>

# %%
sns.barplot(x=df.destination_city,y=df.price)
# Out:
# <Axes: xlabel='destination_city', ylabel='price'>

# %%
sns.boxplot(x=df['class'],y=df.price)
# Out:
# <Axes: xlabel='class', ylabel='price'>

# %%
df.drop(['source_city','destination_city','flight'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#     airline departure_time stops   arrival_time    class  duration  days_left  \
# 0  SpiceJet        Evening  zero          Night  Economy      2.17          1
# 1  SpiceJet  Early_Morning  zero        Morning  Economy      2.33          1
# 2   AirAsia  Early_Morning  zero  Early_Morning  Economy      2.17          1
# 3   Vistara        Morning  zero      Afternoon  Economy      2.25          1
# 4   Vistara        Morning  zero        Morning  Economy      2.33          1
#
#    price
# 0   5953
# 1   5953
# 2   5956
# 3   5955
# 4   5955

# %%
fig = plt.figure(figsize=(10, 8))

plt.scatter(df['duration'] , df['price'], c='blue', marker='o')

plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['duration'] , df['price'], c='blue', marker='o')
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(x=df.days_left,y=df.price)

# %%
df.dtypes
# Out:
# airline            object
# departure_time     object
# stops              object
# arrival_time       object
# class              object
# duration          float64
# days_left           int64
# price               int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df.airline=label_encoder.fit_transform(df.airline)
df.departure_time=label_encoder.fit_transform(df.departure_time)
df.stops=label_encoder.fit_transform(df.stops)
df.arrival_time=label_encoder.fit_transform(df.arrival_time)
df['class']=label_encoder.fit_transform(df['class'])

# %%
df.head()
# Out:
#    airline  departure_time  stops  arrival_time  class  duration  days_left  \
# 0        4               2      2             5      1      2.17          1
# 1        4               1      2             4      1      2.33          1
# 2        0               1      2             1      1      2.17          1
# 3        5               4      2             0      1      2.25          1
# 4        5               4      2             4      1      2.33          1
#
#    price
# 0   5953
# 1   5953
# 2   5956
# 3   5955
# 4   5955

# %%
df.dtypes
# Out:
# airline             int32
# departure_time      int32
# stops               int32
# arrival_time        int32
# class               int32
# duration          float64
# days_left           int64
# price               int64
# dtype: object

# %%
df.corr()
# Out:
#                  airline  departure_time     stops  arrival_time     class  \
# airline         1.000000        0.056885 -0.029838      0.037714 -0.178862
# departure_time  0.056885        1.000000 -0.008518     -0.046282 -0.053340
# stops          -0.029838       -0.008518  1.000000      0.010515  0.100262
# arrival_time    0.037714       -0.046282  0.010515      1.000000 -0.027647
# class          -0.178862       -0.053340  0.100262     -0.027647  1.000000
# duration       -0.001651        0.084348 -0.473860      0.008679 -0.138710
# days_left      -0.010678       -0.001597 -0.007047     -0.004191  0.013039
# price           0.243358        0.058319 -0.202620      0.042043 -0.937860
#
#                 duration  days_left     price
# airline        -0.001651  -0.010678  0.243358
# departure_time  0.084348  -0.001597  0.058319
# stops          -0.473860  -0.007047 -0.202620
# arrival_time    0.008679  -0.004191  0.042043
# class          -0.138710   0.013039 -0.937860
# ...

# %%
X=df.drop(['price'],axis='columns')
y=df.price

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
model_params={
    'linear':{
        'model':LinearRegression(),
        'params':{}
    },
    'lasso':{
        'model':Lasso(),
        'params': {'alpha': [0.01, 0.1, 1, 10, 100]}
    },
    'ridge':{
        'model':Ridge(),
        'params': {'alpha': [0.01, 0.1, 1, 10, 100]}
    }

}

# %%
scores=[]
for model_name,mp in model_params.items():
    regressor=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
    regressor.fit(X_train,y_train)
    scores.append({
        'model':model_name,
        'best_score':regressor.best_score_,
        'best_params':regressor.best_params_
    })
    
grid_df=pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
grid_df
# Out:
#     model  best_score      best_params
# 0  linear    0.904431               {}
# 1   lasso    0.904431  {'alpha': 0.01}
# 2   ridge    0.904431  {'alpha': 0.01}

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.904657460859923

# %%
import pickle
with open('Flight_Price_prediction_model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)
